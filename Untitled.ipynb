# %%
import numpy as np

# %%
X = np.array([[3, -2],[-1, 4]])

# %%
XT = X.T

# %%
XT
# Out:
# array([[ 3, -1],
#        [-2,  4]])

# %%
XTX = XT.dot(X)
XTX
# Out:
# array([[ 10, -10],
#        [-10,  20]])

# %%
XTX_inv = np.linalg.inv(XTX)
XTX_inv
# Out:
# array([[0.2, 0.1],
#        [0.1, 0.1]])

# %%
y = np.array([[-4],[1]])
hat = XTX_inv.dot(XT).dot(y)
hat
# Out:
# array([[-1.4],
#        [-0.1]])
